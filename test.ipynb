# %%
import pandas as pd
import os

df1 = pd.read_csv('test_data/Accelerometer.csv')
df2 = pd.read_csv('test_data\Gyroscope.csv')

combined_df = pd.concat([df1, df2], axis=1)
print(combined_df.head(5))
# combined_df.to_csv('combined_output.csv', index=False)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\A'
# <>:5: SyntaxWarning: invalid escape sequence '\G'
# <>:4: SyntaxWarning: invalid escape sequence '\A'
# <>:5: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\keviny168\AppData\Local\Temp\ipykernel_2020\164383952.py:4: SyntaxWarning: invalid escape sequence '\A'
#   df1 = pd.read_csv('test_data\Accelerometer.csv')
# C:\Users\keviny168\AppData\Local\Temp\ipykernel_2020\164383952.py:5: SyntaxWarning: invalid escape sequence '\G'
#   df2 = pd.read_csv('test_data\Gyroscope.csv')
#                   time  seconds_elapsed    accelZ    accelY    accelX  \
# 0  1743715034904338400         0.030338  0.024807 -0.006061  0.071945
# 1  1743715034914302500         0.040302  0.019996  0.013443  0.088051
# 2  1743715034924265200         0.050265  0.058692  0.027375  0.039782
# 3  1743715034934229200         0.060229  0.096939  0.026085  0.038408
# 4  1743715034944192300         0.070192  0.104008 -0.025497  0.000983
#
#                   time  seconds_elapsed     gyroZ     gyroY     gyroX
# 0  1743715034904338400         0.030338 -0.007174  0.001663 -0.020305
# 1  1743715034914302500         0.040302 -0.005683  0.004457 -0.022755
# 2  1743715034924265200         0.050265 -0.004709  0.005265 -0.030421
# 3  1743715034934229200         0.060229  0.001648  0.008172 -0.037545
# 4  1743715034944192300         0.070192  0.001616  0.003270 -0.042339

# %%
combined_df
# Out:
#                      time  seconds_elapsed    accelZ    accelY    accelX  \
# 0     1743715034904338400         0.030338  0.024807 -0.006061  0.071945
# 1     1743715034914302500         0.040302  0.019996  0.013443  0.088051
# 2     1743715034924265200         0.050265  0.058692  0.027375  0.039782
# 3     1743715034934229200         0.060229  0.096939  0.026085  0.038408
# 4     1743715034944192300         0.070192  0.104008 -0.025497  0.000983
# ...                   ...              ...       ...       ...       ...
# 2542  1743715060231631600        25.357632 -0.202850  0.550839 -0.291118
# 2543  1743715060241595400        25.367595  0.310687  0.668940  0.203198
# 2544  1743715060251559400        25.377559  0.389210  0.891497  0.605934
# 2545  1743715060261522400        25.387522  0.196528  0.747578  0.470359
# 2546  1743715060271486500        25.397487  0.046927  0.541142  0.159747
#
#                      time  seconds_elapsed     gyroZ     gyroY     gyroX
# 0     1743715034904338400         0.030338 -0.007174  0.001663 -0.020305
# 1     1743715034914302500         0.040302 -0.005683  0.004457 -0.022755
# 2     1743715034924265200         0.050265 -0.004709  0.005265 -0.030421
# 3     1743715034934229200         0.060229  0.001648  0.008172 -0.037545
# 4     1743715034944192300         0.070192  0.001616  0.003270 -0.042339
# ...                   ...              ...       ...       ...       ...
# 2542  1743715060231631600        25.357632  0.945949  0.962742  0.144072
# 2543  1743715060241595400        25.367595  0.941868  0.731311  0.071549
# 2544  1743715060251559400        25.377559  0.954036  0.507516  0.016466
# 2545  1743715060261522400        25.387522  0.938752  0.328249  0.024013
# 2546  1743715060271486500        25.397487  0.917573  0.272644  0.078051
#
# [2547 rows x 10 columns]

# %%
|
